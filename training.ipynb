# %%
import os
import sys
import timeit

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.applications.inception_v3 import preprocess_input

import numpy as np
import math
import sklearn
import seaborn
import multiprocessing as mp

# %%
import training_fonts_connection as connection

# %%
# class_num = 319

# %%
# database = connection.training_fonts_connection()

# %%
# data_infos = database.get_all()
# tmp_raw = database.get_unique_content("UTF_8")

# %%
# database.close()

# %%
# data_infos

# %%
input_shape = (100,100,1)
num_classes = 300

# %%
model = InceptionV3(weights=None, include_top=False, input_shape=input_shape )

# %%
model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_5 (InputLayer)        [(None, 100, 100, 1)]        0         []
#
#  conv2d_284 (Conv2D)         (None, 49, 49, 32)           288       ['input_5[0][0]']
#
#  batch_normalization_282 (B  (None, 49, 49, 32)           96        ['conv2d_284[0][0]']
#  atchNormalization)
#
#  activation_282 (Activation  (None, 49, 49, 32)           0         ['batch_normalization_282[0][0
#  )                                                                  ]']
#
#  conv2d_285 (Conv2D)         (None, 47, 47, 32)           9216      ['activation_282[0][0]']
#
#  batch_normalization_283 (B  (None, 47, 47, 32)           96        ['conv2d_285[0][0]']
#  atchNormalization)
#
#  activation_283 (Activation  (None, 47, 47, 32)           0         ['batch_normalization_283[0][0
# ...

# %%
from tensorflow import keras
from tensorflow.keras import layers

input_shape = (100, 100, 1)
num_classes = 300

# Define the Inception V3 model architecture
def inception_v3(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)

    # Pre-defined Inception V3 layers
    x = layers.Conv2D(32, kernel_size=(3, 3), activation="relu")(inputs)
    x = layers.MaxPooling2D(pool_size=(2, 2))(x)
    x = layers.Conv2D(64, kernel_size=(3, 3), activation="relu")(x)
    x = layers.MaxPooling2D(pool_size=(2, 2))(x)
    x = layers.Flatten()(x)
    x = layers.Dense(128, activation="relu")(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    # Create the model
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# Create the Inception V3 model
model = inception_v3(input_shape, num_classes)

# Compile the model
model.compile(
    loss=keras.losses.CategoricalCrossentropy(),
    optimizer=keras.optimizers.Adam(),
    metrics=["accuracy"]
)

# Print the model summary
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_4 (InputLayer)        [(None, 100, 100, 1)]     0
#
#  conv2d_282 (Conv2D)         (None, 98, 98, 32)        320
#
#  max_pooling2d_12 (MaxPooli  (None, 49, 49, 32)        0
#  ng2D)
#
#  conv2d_283 (Conv2D)         (None, 47, 47, 64)        18496
#
#  max_pooling2d_13 (MaxPooli  (None, 23, 23, 64)        0
#  ng2D)
#
#  flatten (Flatten)           (None, 33856)             0
#
#  dense (Dense)               (None, 128)               4333696
#
#  dense_1 (Dense)             (None, 300)               38700
#
# ...
# Total params: 4391212 (16.75 MB)
# Trainable params: 4391212 (16.75 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
