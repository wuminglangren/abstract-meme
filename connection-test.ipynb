# %%
import training_fonts_connection

# %%
testit = training_fonts_connection.training_fonts_connection()

# %%
testit.get_all()
# Out:
# [(989549,
#   '/home/wuming/Documents/abstract-meme/database/fonts/treated_fonts/989549_0xf196d/IosevkaTermNerdFont-ExtraLightItalic_989549_0xf196d_\U000f196d.png',
#   'IosevkaTermNerdFont',
#   'ExtraLightItalic'),
#  (989549,
#   '/home/wuming/Documents/abstract-meme/database/fonts/treated_fonts/989549_0xf196d/GohuFontuni14NerdFontPropo-Regular_989549_0xf196d_\U000f196d.png',
#   'GohuFontuni14NerdFontPropo',
#   'Regular'),
#  (989549,
#   '/home/wuming/Documents/abstract-meme/database/fonts/treated_fonts/989549_0xf196d/IosevkaTermNerdFont-Thin_989549_0xf196d_\U000f196d.png',
#   'IosevkaTermNerdFont',
#   'Thin'),
#  (989549,
#   '/home/wuming/Documents/abstract-meme/database/fonts/treated_fonts/989549_0xf196d/MonoidNerdFontPropo-Bold_989549_0xf196d_\U000f196d.png',
#   'MonoidNerdFontPropo',
#   'Bold'),
#  (989549,
#   '/home/wuming/Documents/abstract-meme/database/fonts/treated_fonts/989549_0xf196d/JetBrainsMonoNLNerdFont-LightItalic_989549_0xf196d_\U000f196d.png',
# ...

# %%
testit.get_unique_content(column_name="utf_8")
# Out:
# ['UTF_8', 'ABS_PATH', 'FONT_NAME', 'FONT_TYPE']
# [(989549,),
#  (986385,),
#  (513,),
#  (651,),
#  (984605,),
#  (985193,),
#  (985372,),
#  (988626,),
#  (463,),
#  (985311,),
#  (9003,),
#  (7691,),
#  (984063,),
#  (987162,),
#  (576,),
#  (62064,),
#  (989090,),
#  (983857,),
#  (235,),
#  (984824,),
#  (60273,),
#  (61512,),
#  (988275,),
#  (987738,),
#  (127396,),
#  (9443,),
#  (129912,),
#  (59037,),
#  (989647,),
#  (984747,),
#  (988615,),
#  (989829,),
#  (9870,),
#  (60112,),
#  (127767,),
#  (984414,),
#  (985768,),
#  (983493,),
#  (60285,),
#  (987949,),
#  (986681,),
#  (984859,),
#  (985249,),
#  (989688,),
#  (300,),
#  (512,),
#  (986640,),
#  (10132,),
#  (120721,),
#  (986160,),
#  (986582,),
#  (988556,),
#  (129848,),
#  (61858,),
#  (7582,),
#  (985959,),
#  (9338,),
#  (42565,),
#  (989406,),
#  (61752,),
#  (987491,),
#  (9679,),
#  (983660,),
#  (7678,),
#  (60153,),
#  (988600,),
#  (984565,),
#  (984297,),
#  (985596,),
#  (986886,),
#  (57878,),
# ...

# %%
len(testit.get_unique_content(column_name="utf_8"))
# Out:
# ['UTF_8', 'ABS_PATH', 'FONT_NAME', 'FONT_TYPE']
# 14724

# %%
testit.close()
